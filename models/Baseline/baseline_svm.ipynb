# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.python.lib.io import file_io

from keras import backend as K
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras import losses
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.python.keras.preprocessing import image_dataset

from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import imutils, cv2, dlib

# %matplotlib inline

# %%
EPOCHS = 50
BS = 128
DROPOUT_RATE = 0.3
SGD_LEARNING_RATE = 0.01
SGD_DECAY = 0.0001

# %%
def svm_loss(layer):
    weights = layer.weights[0]
    weights_tf = tf.convert_to_tensor(weights)
    
    def categorical_hinge_loss(y_true, y_pred):
        pos = K.sum(y_true * y_pred, axis=-1)
        neg = K.max((1.0 - y_true) * y_pred, axis=-1)
        hinge_loss = K.mean(K.maximum(0.0, neg - pos + 1), axis=-1)
        regularization_loss = 0.5*(tf.reduce_sum(tf.square(weights_tf)))
        return regularization_loss + 0.4*hinge_loss
    
    return categorical_hinge_loss

# %%
model = Sequential()
model.add(BatchNormalization(input_shape=(48,48,3)))
model.add(Conv2D(32, (3, 3), activation='relu',padding='same', input_shape=(48,48,3),name="conv1"))
model.add(BatchNormalization())
#model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool1"))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu',padding='same',name="conv2"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool2"))         
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu',padding='same',name="conv3"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool3"))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu',padding='same',name="conv4"))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2),name="maxpool4"))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(1024, activation='relu',name='fc1'))
model.add(Dropout(DROPOUT_RATE))
model.add(BatchNormalization())
model.add(Dense(7, activation='softmax',name='fcsoftmax'))

sgd = SGD(lr=SGD_LEARNING_RATE,momentum=0.9, decay=SGD_DECAY, nesterov=True)
model.compile(optimizer=sgd, loss="categorical_crossentropy", metrics=['accuracy'])
model.load_weights('/content/drive/MyDrive/model/Baseline/baseline-EPOCHS_150-DROPOUT_0.3-test_acc_0.675.h5')
for layer in model.layers[:-1]:
  layer.trainable = False
model.layers.pop()
model.add(Dense(7, use_bias=False, activation='linear', name='svm'))
model.compile(optimizer=sgd, loss=svm_loss(model.get_layer('svm')), metrics=['accuracy'])

# checkpoint
cp_filepath='./model/Baseline-weights-best.hdf5'
rlrop = keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy',mode='max',factor=0.5, patience=10, min_lr=0.00001, verbose=1)
checkpoint = ModelCheckpoint(cp_filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [rlrop,checkpoint]

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_30 (Batc (None, 48, 48, 3)         12
# _________________________________________________________________
# conv1 (Conv2D)               (None, 48, 48, 32)        896
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 48, 48, 32)        128
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 48, 48, 32)        9248
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 48, 48, 32)        128
# _________________________________________________________________
# maxpool2 (MaxPooling2D)      (None, 24, 24, 32)        0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 24, 24, 32)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 24, 24, 64)        18496
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 24, 24, 64)        256
# _________________________________________________________________
# maxpool3 (MaxPooling2D)      (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 12, 12, 64)        36928
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 12, 12, 64)        256
# _________________________________________________________________
# maxpool4 (MaxPooling2D)      (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 1024)              2360320
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 1024)              4096
# _________________________________________________________________
# fcsoftmax (Dense)            (None, 7)                 7175
# _________________________________________________________________
# svm (Dense)                  (None, 7)                 49
# =================================================================
# Total params: 2,437,988
# Trainable params: 7,224
# Non-trainable params: 2,430,764
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# %%bash
# root='./../dataset/train/'
# IFS=$(echo -en "\n\b")
# (for dir in $(ls -1 "$root")
#     do printf "$dir: " && ls -i "$root$dir" | wc -l
#  done)
# Out:
# ls: cannot access './../dataset/train/': No such file or directory

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('./shape_predictor_68_face_landmarks.dat')
fa = FaceAligner(predictor, desiredLeftEye=(0.3,0.3), desiredFaceWidth=48)

# %%
def preprocessing(path, filename):
    image = cv2.imread(path)
    image = imutils.resize(image, width=800)
    face = cv2.normalize(image, None, 0, 255, cv2.NORM_MINMAX)
    gray_face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
    rect = detector(face, 1)
    if (len(rect) > 0):
        rect = rect[0]
        face_aligned = fa.align(face, gray_face, rect)
        cv2.imwrite(filename, face_aligned)

# %%
source = './../dataset'
target = './../dataset2'
for dataset in os.listdir(source):
    dataset_dir = source+'/'+dataset
    if os.path.isdir(dataset_dir):
        for category in os.listdir(dataset_dir):
            category_dir = dataset_dir+'/'+category
            if os.path.isdir(category_dir):
                for file in os.listdir(category_dir):
                    path = category_dir+'/'+file
                    filename = target+'/'+dataset+'/'+category+'/'+file
                    if os.path.isfile(path) and not os.path.exists(filename+'.jpg'):
                        preprocessing(path, filename)
                print("Finish preprocessing {} in {}...".format(category, dataset))
print("Finish preprocessing!")
# Out:
# Finish preprocessing happy in test...
# Finish preprocessing sad in test...
# Finish preprocessing fear in test...
# Finish preprocessing surprise in test...
# Finish preprocessing neutral in test...
# Finish preprocessing angry in test...
# Finish preprocessing disgust in test...
# Finish preprocessing happy in train...
# Finish preprocessing sad in train...
# Finish preprocessing fear in train...
# Finish preprocessing surprise in train...
# Finish preprocessing neutral in train...
# Finish preprocessing angry in train...
# Finish preprocessing disgust in train...
# Finish preprocessing!

# %%
def load_data(train_path, test_path):
    train_data = image_dataset.image_dataset_from_directory(
            train_path, 
            label_mode='categorical',
            batch_size=BS,
            image_size=(48, 48), 
            shuffle=True, 
            seed=1337,
            validation_split=0.2,
            subset="training")
    val_data = image_dataset.image_dataset_from_directory(
            train_path, 
            label_mode='categorical',
            batch_size=BS,
            image_size=(48, 48), 
            shuffle=True, 
            seed=1337,
            validation_split=0.2,
            subset="validation")
    test_data = image_dataset.image_dataset_from_directory(
            test_path, 
            label_mode='categorical',
            batch_size=BS,
            image_size=(48, 48), 
            shuffle=True)
    return train_data, val_data, test_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip -q '/content/drive/My Drive/Colab Notebooks/train.zip' -d dataset
! unzip -q '/content/drive/My Drive/Colab Notebooks/test.zip' -d dataset

# %%
train_ds, val_ds, test_ds = load_data('/content/train', '/content/test')
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 22035 files belonging to 7 classes.
# Using 17628 files for training.
# Found 22035 files belonging to 7 classes.
# Using 4407 files for validation.
# Found 5512 files belonging to 7 classes.

# %%
train_ds.take(1)
# Out:
# <TakeDataset shapes: ((None, 48, 48, 3), (None, 7)), types: (tf.float32, tf.float32)>

# %%
history = model.fit(
    train_ds, 
    validation_data=val_ds, 
    shuffle=True, 
    epochs=EPOCHS,
    callbacks=callbacks_list,
    use_multiprocessing=False,)
# Out:
# Epoch 1/50
# 138/138 [==============================] - ETA: 0s - loss: 4.1783 - accuracy: 0.6011
# Epoch 00001: val_accuracy improved from -inf to 0.66281, saving model to ./model/Baseline-weights-best.hdf5
# 138/138 [==============================] - 69s 499ms/step - loss: 4.1783 - accuracy: 0.6011 - val_loss: 4.1369 - val_accuracy: 0.6628
# Epoch 2/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8816 - accuracy: 0.9851
# Epoch 00002: val_accuracy improved from 0.66281 to 0.66417, saving model to ./model/Baseline-weights-best.hdf5
# 138/138 [==============================] - 69s 498ms/step - loss: 3.8816 - accuracy: 0.9851 - val_loss: 4.1030 - val_accuracy: 0.6642
# Epoch 3/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8485 - accuracy: 0.9837
# Epoch 00003: val_accuracy improved from 0.66417 to 0.66462, saving model to ./model/Baseline-weights-best.hdf5
# 138/138 [==============================] - 68s 496ms/step - loss: 3.8485 - accuracy: 0.9837 - val_loss: 4.1051 - val_accuracy: 0.6646
# Epoch 4/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8462 - accuracy: 0.9849
# Epoch 00004: val_accuracy did not improve from 0.66462
# 138/138 [==============================] - 69s 497ms/step - loss: 3.8462 - accuracy: 0.9849 - val_loss: 4.1070 - val_accuracy: 0.6637
# Epoch 5/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8456 - accuracy: 0.9855
# Epoch 00005: val_accuracy did not improve from 0.66462
# 138/138 [==============================] - 69s 497ms/step - loss: 3.8456 - accuracy: 0.9855 - val_loss: 4.1085 - val_accuracy: 0.6633
# Epoch 6/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8446 - accuracy: 0.9855
# Epoch 00006: val_accuracy did not improve from 0.66462
# 138/138 [==============================] - 69s 498ms/step - loss: 3.8446 - accuracy: 0.9855 - val_loss: 4.1100 - val_accuracy: 0.6642
# Epoch 7/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8427 - accuracy: 0.9863
# Epoch 00007: val_accuracy improved from 0.66462 to 0.66485, saving model to ./model/Baseline-weights-best.hdf5
# 138/138 [==============================] - 68s 494ms/step - loss: 3.8427 - accuracy: 0.9863 - val_loss: 4.1109 - val_accuracy: 0.6649
# Epoch 8/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8428 - accuracy: 0.9850
# Epoch 00008: val_accuracy improved from 0.66485 to 0.66508, saving model to ./model/Baseline-weights-best.hdf5
# 138/138 [==============================] - 68s 494ms/step - loss: 3.8428 - accuracy: 0.9850 - val_loss: 4.1119 - val_accuracy: 0.6651
# Epoch 9/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8412 - accuracy: 0.9865
# Epoch 00009: val_accuracy did not improve from 0.66508
# 138/138 [==============================] - 68s 496ms/step - loss: 3.8412 - accuracy: 0.9865 - val_loss: 4.1132 - val_accuracy: 0.6637
# Epoch 10/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8412 - accuracy: 0.9863
# Epoch 00010: val_accuracy did not improve from 0.66508
# 138/138 [==============================] - 69s 502ms/step - loss: 3.8412 - accuracy: 0.9863 - val_loss: 4.1144 - val_accuracy: 0.6644
# Epoch 11/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8421 - accuracy: 0.9846
# Epoch 00011: val_accuracy did not improve from 0.66508
# 138/138 [==============================] - 68s 493ms/step - loss: 3.8421 - accuracy: 0.9846 - val_loss: 4.1152 - val_accuracy: 0.6642
# Epoch 12/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8418 - accuracy: 0.9850
# Epoch 00012: val_accuracy did not improve from 0.66508
# 138/138 [==============================] - 68s 494ms/step - loss: 3.8418 - accuracy: 0.9850 - val_loss: 4.1160 - val_accuracy: 0.6635
# Epoch 13/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8419 - accuracy: 0.9852
# Epoch 00013: val_accuracy did not improve from 0.66508
# 138/138 [==============================] - 68s 496ms/step - loss: 3.8419 - accuracy: 0.9852 - val_loss: 4.1167 - val_accuracy: 0.6651
# Epoch 14/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8408 - accuracy: 0.9867
# Epoch 00014: val_accuracy did not improve from 0.66508
# 138/138 [==============================] - 69s 497ms/step - loss: 3.8408 - accuracy: 0.9867 - val_loss: 4.1172 - val_accuracy: 0.6642
# Epoch 15/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8426 - accuracy: 0.9849
# Epoch 00015: val_accuracy did not improve from 0.66508
# 138/138 [==============================] - 69s 500ms/step - loss: 3.8426 - accuracy: 0.9849 - val_loss: 4.1177 - val_accuracy: 0.6639
# Epoch 16/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8422 - accuracy: 0.9847
# Epoch 00016: val_accuracy improved from 0.66508 to 0.66531, saving model to ./model/Baseline-weights-best.hdf5
# 138/138 [==============================] - 68s 496ms/step - loss: 3.8422 - accuracy: 0.9847 - val_loss: 4.1183 - val_accuracy: 0.6653
# Epoch 17/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8418 - accuracy: 0.9853
# Epoch 00017: val_accuracy improved from 0.66531 to 0.66599, saving model to ./model/Baseline-weights-best.hdf5
# 138/138 [==============================] - 69s 498ms/step - loss: 3.8418 - accuracy: 0.9853 - val_loss: 4.1188 - val_accuracy: 0.6660
# Epoch 18/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8419 - accuracy: 0.9857
# Epoch 00018: val_accuracy did not improve from 0.66599
# 138/138 [==============================] - 69s 498ms/step - loss: 3.8419 - accuracy: 0.9857 - val_loss: 4.1194 - val_accuracy: 0.6658
# Epoch 19/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8417 - accuracy: 0.9846
# Epoch 00019: val_accuracy did not improve from 0.66599
# 138/138 [==============================] - 68s 495ms/step - loss: 3.8417 - accuracy: 0.9846 - val_loss: 4.1198 - val_accuracy: 0.6651
# Epoch 20/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8422 - accuracy: 0.9850
# Epoch 00020: val_accuracy did not improve from 0.66599
# 138/138 [==============================] - 68s 496ms/step - loss: 3.8422 - accuracy: 0.9850 - val_loss: 4.1207 - val_accuracy: 0.6655
# Epoch 21/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8414 - accuracy: 0.9855
# Epoch 00021: val_accuracy did not improve from 0.66599
# 138/138 [==============================] - 68s 495ms/step - loss: 3.8414 - accuracy: 0.9855 - val_loss: 4.1211 - val_accuracy: 0.6651
# Epoch 22/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8414 - accuracy: 0.9855
# Epoch 00022: val_accuracy did not improve from 0.66599
# 138/138 [==============================] - 68s 496ms/step - loss: 3.8414 - accuracy: 0.9855 - val_loss: 4.1215 - val_accuracy: 0.6658
# Epoch 23/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8409 - accuracy: 0.9860
# Epoch 00023: val_accuracy did not improve from 0.66599
# 138/138 [==============================] - 68s 495ms/step - loss: 3.8409 - accuracy: 0.9860 - val_loss: 4.1218 - val_accuracy: 0.6660
# Epoch 24/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8427 - accuracy: 0.9838
# Epoch 00024: val_accuracy did not improve from 0.66599
# 138/138 [==============================] - 68s 494ms/step - loss: 3.8427 - accuracy: 0.9838 - val_loss: 4.1222 - val_accuracy: 0.6660
# Epoch 25/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8419 - accuracy: 0.9851
# Epoch 00025: val_accuracy improved from 0.66599 to 0.66644, saving model to ./model/Baseline-weights-best.hdf5
# 138/138 [==============================] - 68s 494ms/step - loss: 3.8419 - accuracy: 0.9851 - val_loss: 4.1227 - val_accuracy: 0.6664
# Epoch 26/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8419 - accuracy: 0.9851
# Epoch 00026: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 68s 494ms/step - loss: 3.8419 - accuracy: 0.9851 - val_loss: 4.1232 - val_accuracy: 0.6658
# Epoch 27/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8412 - accuracy: 0.9852
# Epoch 00027: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 69s 496ms/step - loss: 3.8412 - accuracy: 0.9852 - val_loss: 4.1238 - val_accuracy: 0.6653
# Epoch 28/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8415 - accuracy: 0.9847
# Epoch 00028: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 68s 496ms/step - loss: 3.8415 - accuracy: 0.9847 - val_loss: 4.1242 - val_accuracy: 0.6635
# Epoch 29/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8420 - accuracy: 0.9851
# Epoch 00029: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 68s 494ms/step - loss: 3.8420 - accuracy: 0.9851 - val_loss: 4.1244 - val_accuracy: 0.6642
# Epoch 30/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8425 - accuracy: 0.9842
# Epoch 00030: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 68s 495ms/step - loss: 3.8425 - accuracy: 0.9842 - val_loss: 4.1248 - val_accuracy: 0.6637
# Epoch 31/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8410 - accuracy: 0.9857
# Epoch 00031: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 68s 496ms/step - loss: 3.8410 - accuracy: 0.9857 - val_loss: 4.1251 - val_accuracy: 0.6649
# Epoch 32/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8426 - accuracy: 0.9836
# Epoch 00032: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 69s 499ms/step - loss: 3.8426 - accuracy: 0.9836 - val_loss: 4.1252 - val_accuracy: 0.6646
# Epoch 33/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8409 - accuracy: 0.9864
# Epoch 00033: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 68s 496ms/step - loss: 3.8409 - accuracy: 0.9864 - val_loss: 4.1256 - val_accuracy: 0.6658
# Epoch 34/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8425 - accuracy: 0.9840
# Epoch 00034: val_accuracy did not improve from 0.66644
# 138/138 [==============================] - 68s 496ms/step - loss: 3.8425 - accuracy: 0.9840 - val_loss: 4.1257 - val_accuracy: 0.6658
# Epoch 35/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8408 - accuracy: 0.9870
# Epoch 00035: val_accuracy improved from 0.66644 to 0.66667, saving model to ./model/Baseline-weights-best.hdf5
# 138/138 [==============================] - 69s 498ms/step - loss: 3.8408 - accuracy: 0.9870 - val_loss: 4.1257 - val_accuracy: 0.6667
# Epoch 36/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8419 - accuracy: 0.9857
# Epoch 00036: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 502ms/step - loss: 3.8419 - accuracy: 0.9857 - val_loss: 4.1261 - val_accuracy: 0.6653
# Epoch 37/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8413 - accuracy: 0.9856
# Epoch 00037: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 70s 505ms/step - loss: 3.8413 - accuracy: 0.9856 - val_loss: 4.1267 - val_accuracy: 0.6651
# Epoch 38/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8410 - accuracy: 0.9864
# Epoch 00038: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 70s 504ms/step - loss: 3.8410 - accuracy: 0.9864 - val_loss: 4.1271 - val_accuracy: 0.6646
# Epoch 39/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8415 - accuracy: 0.9851
# Epoch 00039: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 70s 504ms/step - loss: 3.8415 - accuracy: 0.9851 - val_loss: 4.1275 - val_accuracy: 0.6653
# Epoch 40/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8417 - accuracy: 0.9858
# Epoch 00040: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 70s 504ms/step - loss: 3.8417 - accuracy: 0.9858 - val_loss: 4.1277 - val_accuracy: 0.6658
# Epoch 41/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8408 - accuracy: 0.9853
# Epoch 00041: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 502ms/step - loss: 3.8408 - accuracy: 0.9853 - val_loss: 4.1277 - val_accuracy: 0.6651
# Epoch 42/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8412 - accuracy: 0.9856
# Epoch 00042: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 500ms/step - loss: 3.8412 - accuracy: 0.9856 - val_loss: 4.1280 - val_accuracy: 0.6664
# Epoch 43/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8407 - accuracy: 0.9860
# Epoch 00043: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 501ms/step - loss: 3.8407 - accuracy: 0.9860 - val_loss: 4.1281 - val_accuracy: 0.6653
# Epoch 44/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8414 - accuracy: 0.9858
# Epoch 00044: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 499ms/step - loss: 3.8414 - accuracy: 0.9858 - val_loss: 4.1283 - val_accuracy: 0.6660
# Epoch 45/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8416 - accuracy: 0.9854
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00045: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 500ms/step - loss: 3.8416 - accuracy: 0.9854 - val_loss: 4.1284 - val_accuracy: 0.6660
# Epoch 46/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8405 - accuracy: 0.9867
# Epoch 00046: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 497ms/step - loss: 3.8405 - accuracy: 0.9867 - val_loss: 4.1286 - val_accuracy: 0.6655
# Epoch 47/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8411 - accuracy: 0.9853
# Epoch 00047: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 498ms/step - loss: 3.8411 - accuracy: 0.9853 - val_loss: 4.1287 - val_accuracy: 0.6651
# Epoch 48/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8414 - accuracy: 0.9857
# Epoch 00048: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 497ms/step - loss: 3.8414 - accuracy: 0.9857 - val_loss: 4.1289 - val_accuracy: 0.6646
# Epoch 49/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8407 - accuracy: 0.9861
# Epoch 00049: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 499ms/step - loss: 3.8407 - accuracy: 0.9861 - val_loss: 4.1290 - val_accuracy: 0.6655
# Epoch 50/50
# 138/138 [==============================] - ETA: 0s - loss: 3.8419 - accuracy: 0.9850
# Epoch 00050: val_accuracy did not improve from 0.66667
# 138/138 [==============================] - 69s 501ms/step - loss: 3.8419 - accuracy: 0.9850 - val_loss: 4.1291 - val_accuracy: 0.6653

# %%
epoch_str = '-EPOCHS_' + str(EPOCHS)
dropout_str = '-DROPOUT_' + str(DROPOUT_RATE)
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
# plt.savefig('./../results/baseline' + epoch_str + dropout_str + '-accuracy.png')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
# plt.savefig('./../results/baseline' + epoch_str + dropout_str + '-loss.png')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
print('\n# Evaluate on validation data')
results_val = model.evaluate(val_ds, batch_size=BS)
print('validation loss, validation accuracy:', results_val)
# Out:
# # Evaluate on validation data
# 35/35 [==============================] - 10s 292ms/step - loss: 4.1291 - accuracy: 0.6653
# validation loss, validation accuracy: [4.129126071929932, 0.6653051972389221]

# %%
print('\n# Evaluate on test data')
results_test = model.evaluate(test_ds, batch_size=BS)
print('test loss, test accuracy:', results_test)
# Out:
# # Evaluate on test data
# 44/44 [==============================] - 15s 333ms/step - loss: 4.1193 - accuracy: 0.6745
# test loss, test accuracy: [4.119266986846924, 0.6745283007621765]

# %%
test_acc = '-test_acc_%.3f' % results_test[1]
model.save('./baseline' + epoch_str + dropout_str + test_acc + '_svm.h5')
